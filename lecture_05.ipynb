# %%
# Install dependencies and run setup script
# %run example_definitions/lecture_05_definitions.ipynb
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py", line 596, in run_forever
#     self._run_once()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py", line 1890, in _run_once
#     handle._run()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/881993288.py", line 2, in <module>
#     get_ipython().run_line_magic('run', 'example_definitions/lecture_05_definitions.ipynb')
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2456, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/magics/execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2976, in safe_execfile_ipy
#     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/3156757073.py", line 11, in <module>
#     from sklearn_extra.cluster import KMedoids
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/__init__.py", line 1, in <module>
#     from . import kernel_approximation, kernel_methods  # noqa
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/__init__.py", line 1, in <module>
#     from ._fastfood import Fastfood
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/_fastfood.py", line 11, in <module>
#     from ..utils._cyfht import fht2 as cyfht
# Requirement already satisfied: scikit-learn-extra in ./venv/lib/python3.9/site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.13.3 in ./venv/lib/python3.9/site-packages (from scikit-learn-extra) (2.0.2)
# Requirement already satisfied: scipy>=0.19.1 in ./venv/lib/python3.9/site-packages (from scikit-learn-extra) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in ./venv/lib/python3.9/site-packages (from scikit-learn-extra) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.9/site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.9/site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.6.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/stefanschweng/Documents/boku_university_ddai/venv/bin/python3 -m pip install --upgrade pip' command.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py", line 596, in run_forever
#     self._run_once()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/base_events.py", line 1890, in _run_once
#     handle._run()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/881993288.py", line 2, in <module>
#     get_ipython().run_line_magic('run', 'example_definitions/lecture_05_definitions.ipynb')
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2456, in run_line_magic
#     result = fn(*args, **kwargs)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/magics/execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2976, in safe_execfile_ipy
#     result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/3156757073.py", line 14, in <module>
#     from sklearn_extra.cluster import KMedoids
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/__init__.py", line 1, in <module>
#     from . import kernel_approximation, kernel_methods  # noqa
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/__init__.py", line 1, in <module>
#     from ._fastfood import Fastfood
#   File "/Users/stefanschweng/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/_fastfood.py", line 11, in <module>
#     from ..utils._cyfht import fht2 as cyfht
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/3156757073.py:11
#      10 try:
# ---> 11     from sklearn_extra.cluster import KMedoids
#      12 except ImportError:
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/__init__.py:1
# ----> 1 from . import kernel_approximation, kernel_methods  # noqa
#       3 from ._version import __version__
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/__init__.py:1
# ----> 1 from ._fastfood import Fastfood
#       4 __all__ = ["Fastfood"]
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/_fastfood.py:11
#       9 from sklearn.utils import check_array, check_random_state
# ---> 11 from ..utils._cyfht import fht2 as cyfht
#      14 class Fastfood(BaseEstimator, TransformerMixin):
#
# File sklearn_extra/utils/_cyfht.pyx:1, in init sklearn_extra.utils._cyfht()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File /var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/3156757073.py:14
#      12 except ImportError:
#      13     get_ipython().system('pip install scikit-learn-extra')
# ---> 14     from sklearn_extra.cluster import KMedoids
#      17 def sort_clusters_by_y(centers, labels):
#      18     """
#      19     Sort clusters by their y-coordinate and relabel points accordingly.
#      20     Returns sorted centers and updated labels.
#      21     """
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/__init__.py:1
# ----> 1 from . import kernel_approximation, kernel_methods  # noqa
#       3 from ._version import __version__
#       5 __all__ = ["__version__"]
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/__init__.py:1
# ----> 1 from ._fastfood import Fastfood
#       4 __all__ = ["Fastfood"]
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/_fastfood.py:11
#       8 from sklearn.base import TransformerMixin
#       9 from sklearn.utils import check_array, check_random_state
# ---> 11 from ..utils._cyfht import fht2 as cyfht
#      14 class Fastfood(BaseEstimator, TransformerMixin):
#      15     """Approximates feature map of an RBF kernel by Monte Carlo approximation
#      16     of its Fourier transform.
#      17
#    (...)
#      55
#      56     """
#
# File sklearn_extra/utils/_cyfht.pyx:1, in init sklearn_extra.utils._cyfht()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/3156757073.py:11
#      10 try:
# ---> 11     from sklearn_extra.cluster import KMedoids
#      12 except ImportError:
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/__init__.py:1
# ----> 1 from . import kernel_approximation, kernel_methods  # noqa
#       3 from ._version import __version__
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/__init__.py:1
# ----> 1 from ._fastfood import Fastfood
#       4 __all__ = ["Fastfood"]
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/_fastfood.py:11
#       9 from sklearn.utils import check_array, check_random_state
# ---> 11 from ..utils._cyfht import fht2 as cyfht
#      14 class Fastfood(BaseEstimator, TransformerMixin):
#
# File sklearn_extra/utils/_cyfht.pyx:1, in init sklearn_extra.utils._cyfht()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[74], line 2
#       1 # Install dependencies and run setup script
# ----> 2 get_ipython().run_line_magic('run', 'example_definitions/lecture_05_definitions.ipynb')
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/magics/execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2978, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2976 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2977 if raise_exceptions:
# -> 2978     result.raise_error()
#    2979 elif not result.success:
#    2980     break
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:294, in ExecutionResult.raise_error(self)
#     292     raise self.error_before_exec
#     293 if self.error_in_exec is not None:
# --> 294     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/folders/cq/4tnxw40526g11yg03vsxx1vr0000gn/T/ipykernel_30517/3156757073.py:14
#      12 except ImportError:
#      13     get_ipython().system('pip install scikit-learn-extra')
# ---> 14     from sklearn_extra.cluster import KMedoids
#      17 def sort_clusters_by_y(centers, labels):
#      18     """
#      19     Sort clusters by their y-coordinate and relabel points accordingly.
#      20     Returns sorted centers and updated labels.
#      21     """
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/__init__.py:1
# ----> 1 from . import kernel_approximation, kernel_methods  # noqa
#       3 from ._version import __version__
#       5 __all__ = ["__version__"]
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/__init__.py:1
# ----> 1 from ._fastfood import Fastfood
#       4 __all__ = ["Fastfood"]
#
# File ~/Documents/boku_university_ddai/venv/lib/python3.9/site-packages/sklearn_extra/kernel_approximation/_fastfood.py:11
#       8 from sklearn.base import TransformerMixin
#       9 from sklearn.utils import check_array, check_random_state
# ---> 11 from ..utils._cyfht import fht2 as cyfht
#      14 class Fastfood(BaseEstimator, TransformerMixin):
#      15     """Approximates feature map of an RBF kernel by Monte Carlo approximation
#      16     of its Fourier transform.
#      17
#    (...)
#      55
#      56     """
#
# File sklearn_extra/utils/_cyfht.pyx:1, in init sklearn_extra.utils._cyfht()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).

# %%
loss_functions_visualize()

# %%
linear_reg_loss_functions_demo_interact()
# Out:
# VBox(children=(Label(value='📊 Controls', layout=Layout(margin='0 0 0 0')),))
# interactive(children=(IntSlider(value=50, description='Number of Outliers', layout=Layout(width='500px'), max=…

# %%
polynomial_regression_loss_demo_interact()
# Out:
# VBox(children=(Label(value='📊 Controls', layout=Layout(margin='0 0 0 0')),))
# interactive(children=(IntSlider(value=10, description='Number of Outliers', layout=Layout(width='500px'), max=…

# %%
polynomial_overfitting_demo_interact()

# %%
binary_classification_demo_interact()

# %%
multi_class_classification_demo_interact()

# %%
clustering_demo_interact()
