# %%
# %run example_definitions/lecture_05/loss_functions_visual.ipynb
loss_functions_visualize()

# %%
# %run example_definitions/lecture_05/linear_reg_loss_functions_demo.ipynb
linear_reg_loss_functions_demo_interact()

# %%
# %run example_definitions/lecture_05/polynomial_overfitting_demo.ipynb
polynomial_overfitting_demo_interact()

# %%
# %run example_definitions/lecture_05/polynomial_regression_loss_demo.ipynb
polynomial_regression_loss_demo_interact()

# %%
# %run example_definitions/lecture_05/binary_classification_demo.ipynb
binary_classification_demo_interact()

# %%
# %run example_definitions/lecture_05/multi_class_classification_demo.ipynb
multi_class_classification_demo_interact()

# %%
# %run example_definitions/lecture_05/clustering_demo.ipynb
clustering_demo_interact()

# %%
# %run example_definitions/lecture_05/gradient_descent_demo.ipynb
gradient_descent_interact()

# %%
# %run example_definitions/lecture_05/gradient_descent_3d_demo.ipynb
gradient_descent_3D_convergence_interact()
