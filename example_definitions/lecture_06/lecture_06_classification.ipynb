# %%
# %run example_definitions/lecture_06/visualize_iris_dataset.ipynb
df_loaded = load_and_visualize_iris_dataset()
# Out:
# Sample Data (showing first 5 rows of dataset):
#    sepal length (cm)  sepal width (cm)  target
# 0                5.1               3.5       0
# 1                4.9               3.0       0
# 2                4.7               3.2       0
# 3                4.6               3.1       0
# 4                5.0               3.6       0

# %%
# %run example_definitions/lecture_06/logistic_regression.ipynb
logistic_regression_interact()
# Out:
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
# %run example_definitions/lecture_06/mlp_classification.ipynb
mlp_classification_interact()
# Out:
# Description:
# Easier MLPs (i.e. less Neurons) perform better on the TEST Set --> better generalization!
# VBox(children=(Label(value='📊 Controls', layout=Layout(margin='0 0 0 0')),))
# interactive(children=(IntSlider(value=100, continuous_update=False, description='Hidden Layer 1 Neurons:', lay…
