# %%
# %run example_definitions/lecture_06/visualize_phenotyping_dataset.ipynb
df_loaded = load_and_visualize_phenotyping_dataset()
# Out:
# Sample Data (showing first 5 rows of dataset):
#    days_of_phenotyping   species  nitrogen_applied  drought_stress  \
# 0                    1  barley_1                25               0
# 1                    2  barley_1                25               0
# 2                    3  barley_1                25               0
# 3                    4  barley_1                25               0
# 4                    5  barley_1                25               0
#
#    digital_biomass
# 0         5.498560
# 1         5.540867
# 2         5.703696
# 3         5.717730
# 4         5.708416

# %%
# %run example_definitions/lecture_06/linear_regression.ipynb
linear_reg_interact(df_loaded)
# Out:
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %%
# %run example_definitions/lecture_06/polynomial_regression.ipynb
polynomial_reg_interact(df_loaded)
# Out:
# ...
# interactive(children=(IntSlider(value=3, description='Polynomial Degree', layout=Layout(width='500px'), max=10…

# %%
# %run example_definitions/lecture_06/mlp_regression.ipynb
mlp_regression_interact(df_loaded)
# Out:
# Description:
# You can adjust the number of neurons in each hidden layer of the MLP regression model using the sliders below.The model will retrain and display updated performance metrics and prediction plots based on your selections.
#
#  Note: Always keep the perfomance metrics (RMSE and R² score) in mind. A more complex model (more neurons) does not necessarily lead to better results!
# ...
# interactive(children=(IntSlider(value=100, continuous_update=False, description='Hidden Layer 1 Neurons:', lay…
