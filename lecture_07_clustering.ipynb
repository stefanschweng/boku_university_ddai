# %%
# %run example_definitions/lecture_07/k-means_clustering_demo.ipynb
kmeans_clustering_demo_interact()
# Out:
# Description:
# Here you can see synthetic data with 5 true clusters.You can increase the noise to make clusters overlap, and change k to see how K-Means behaves when the assumed number of clusters differs from the true structure.
# ...
# interactive(children=(FloatSlider(value=1.0, description='Noise', layout=Layout(width='500px'), max=3.0, min=0…
